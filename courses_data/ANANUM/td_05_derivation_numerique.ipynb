# %% [markdown]
# ***
# # IAN - TD 05 - Dérivation numérique
# ***

# %% [markdown]
# <center>
#     <img src="data:image/jpeg;base64,..." width="20%"/>
# </center>

# %% [markdown]
# ***
# ## Exercice 05.01 : Méthode de la limite
# ***

# %% [markdown]
# 1. Rappeler ce qu'est la méthode de la limite.

# %% [markdown]
# 2. Ecrire une fonction `approximer_df` qui prend en paramètres une fonction `f`, un point `x0` et un pas `h` et retourne la valeur du nombre dérivé au point `x0`.

# %% [markdown]
# 3. Soit la fonction $f(x)=\ln(x)$ et sa dérivée $f'(x)=\frac{1}{x}$.
#
#    Tracer le graphe de la dérivée exacte $f'$ ainsi que le graphe de son approximation avec la fonction précédente en utilisant un pas $h= 0,1$.
#
#    Remarque : le logarithme néperien est noté `log` dans la librairie `math`.

# %% [markdown]
# 5. Ecrire une fonction `deriver1`, qui prend en paramètres une fonction `f` et une valeur `h` et qui renvoie la fonction dérivée.

# %% [markdown]
# 6. Comparer les résultats de la résolution de l’équation $\ln(𝑥) − 1 = 0$ avec la méthode de Newton selon la manière de calculer la dérivée (analytique ou approximative).

# %% [markdown]
# ***
# ## Exercice 05.02 : Méthode de la dérivée centrée
# ***

# %% [markdown]
# 1. Rappeler l'approximation utilisée dans la méthode de la dérivée centrée.

# %% [markdown]
# 2. En utilisant cette approximation de la dérivée, tracer sur un même graphique la dérivée formelle $f'$ de `ln` et son approximation avec la fonction précédente en utilisant un $h=0,1$.

# %% [markdown]
# 3. Afficher l’erreur d’approximation de la dérivée au point $x=1$  pour plusieurs valeurs de $h$. On pourra comparer avec la première méthode.

# %% [markdown]
# ***
# ## Exercice 05.03 - Calculs des erreurs
# ***

# %% [markdown]
# Prouver les formules :
# 1. $\frac{f(x_{0}+h)-f(x_{0})}{h}-f'(x_{0})=\frac{f''(x_{0})}{2}h+o(h)$ (pour $h\rightarrow0)$

# %% [markdown]
# 2. $\frac{f(x_{0}+h)-f(x_{0}-h)}{2h}-f'(x_{0})=\frac{f'''(x_{0})}{6}h^{2}+o(h^{2})$ (pour $h\rightarrow0)$

# %% [markdown]
# ***
# ## Exercice 05.04 - Du calcul formel avec des polynômes (facultatif)
# ***

# %% [markdown]
# 1. Quel est le polynôme représenté par la liste python `[-4,-5,1]` ? Quelle est la valeur prise par ce polynôme en $x=1$ ?

# %% [markdown]
# 2. Réaliser une fonction `evaluer`, qui prend en paramètres un polynôme (sous forme d'une liste python) et une valeur `x` et qui retourne la valeur prise par le polynôme en `x`. On pourra tester cette fonction avec le polynome précédent en $x=1$.

# %% [markdown]
# 3. Implémenter une fonction `deriver`qui renvoie la dérivée d'un polynôme `P` passé en paramètre. Tester la fonction en calculant la dérivée du polynôme précédent. On donnera une réponse sous la forme de liste.

# %% [markdown]
# 4. Ecrire une fonction `creer_f` aui prend en paramètre un polynôme `P` et qui retroune la fonction polynômiale associée à `P`.

# %% [markdown]
# 5. Utiliser les fonctions précédentes pour trouver la racine `r` de $f(x) = x^2 − 5x − 4$ avec la méthode de Newton.
